# %%
import cv2


# TODO: pass config in runtime later
def resize_util(img, u_width, u_height=None):
        if u_height is None:
            h, w = img.shape[:2]
            u_height = int(h * u_width / w)
        return cv2.resize(img, (int(u_width), int(u_height)))


marker =im_gray = cv2.imread("OMRChecker-master/samples/sample3/omr_marker.jpg", cv2.IMREAD_GRAYSCALE)
cv2.imshow("imaage",marker)
print(marker.shape)
print(type(marker.shape))
# hh, ww = marker.shape[:2]
# marker = resize_util(  marker, ww  / 17)
# marker = cv2.GaussianBlur(marker, (5, 5), 0)
# marker = cv2.normalize(marker, None, alpha=0, beta=255, norm_type=cv2.NORM_MINMAX)
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# /tmp/ipykernel_130/1039468069.py in <module>
# ----> 1 import cv2
#       2
#       3
#       4 # TODO: pass config in runtime later
#       5 def resize_util(img, u_width, u_height=None):
#
# ImportError: libGL.so.1: cannot open shared object file: No such file or directory
